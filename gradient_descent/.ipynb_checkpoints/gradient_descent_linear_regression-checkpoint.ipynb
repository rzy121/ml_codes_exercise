# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
plt.style.use('bmh')
# %matplotlib inline

# %% [markdown]
# ### Load data from UCI database

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'

cols = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'bk', 'lstat', 'medv']

df = pd.read_csv (url, header=None, names = cols, delim_whitespace=True)

df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    ptratio      bk  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### Create input variable matrix X and dependent variant y

# %%
# take 'rm' & 'age' as inputs, 'medv' as dependent

X = df.loc[:, ['rm', 'age']].values
y = df.medv.values

# %% [markdown]
# ### Codes for algorithm

# %%
# define cost function

def cost(theta, X, y):
    
    cost = (X.dot(theta) - y).dot(X.dot(theta) - y)*(1/(2*len(y)))
    
    return cost

# %%
# define gradient descent

def gradient_descent(X, y, theta, lr  = 0.001, n = 100):
    
    m = len(y)
    cost_history = np.zeros(n)
    theta_history = np.zeros([theta.shape[0], n])
    theta_temp = np.zeros(theta.shape)
    
    for i in range(n):        
        
        for j in range(len(theta)):
            
            theta[j] = theta[j] - lr * (1/m) * X[:, j].dot(X.dot(theta) - y)
            
            theta_history[:, i] = theta.T
            cost_history[i] = cost(theta, X, y)
            print(theta)
        
    return theta, cost_history, theta_history

# %% [markdown]
# ### Test Results

# %%
t = np.random.randn(2) * 100
t
# Out:
# array([241.97423564,  18.72137557])

# %%
theta, cost_hist, theta_hist = gradient_descent(X, y, t, n = 100)
# Out:
# [224.46441404  18.72137557]
# [ 224.46441404 -178.34563619]
# [ 291.64981239 -178.34563619]
# [291.64981239 678.50130916]
# [ -9.06162911 678.50130916]
# [   -9.06162911 -3043.40632154]
# [ 1288.6246539  -3043.40632154]
# [ 1288.6246539  13127.16959102]
# [-4357.89679442 13127.16959102]
# [ -4357.89679442 -57125.54127134]
# [ 20164.88927137 -57125.54127134]
# [ 20164.88927137 248089.39475526]
# [-86383.40700297 248089.39475526]
# [  -86383.40700297 -1077922.17450415]
# [  376509.22628124 -1077922.17450415]
# [ 376509.22628124 4682961.55627499]
# [-1634545.28277168  4682961.55627499]
# [ -1634545.28277168 -20345309.29810547]
# [  7102511.78461924 -20345309.29810547]
# [ 7102511.78461924 88390501.26226899]
# [-30855811.04878985  88390501.26226899]
# [-3.08558110e+07 -3.84014344e+08]
# [ 1.34054853e+08 -3.84014344e+08]
# [1.34054853e+08 1.66835770e+09]
# [-5.82402746e+08  1.66835770e+09]
# [-5.82402746e+08 -7.24821260e+09]
# [ 2.53026123e+09 -7.24821260e+09]
# [2.53026123e+09 3.14900006e+10]
# [-1.09927680e+10  3.14900006e+10]
# [-1.09927680e+10 -1.36808921e+11]
# [ 4.77582957e+10 -1.36808921e+11]
# [4.77582957e+10 5.94369019e+11]
# [-2.07486844e+11  5.94369019e+11]
# [-2.07486844e+11 -2.58224777e+12]
# [ 9.01430635e+11 -2.58224777e+12]
# [9.01430635e+11 1.12186257e+13]
# [-3.91628294e+12  1.12186257e+13]
# [-3.91628294e+12 -4.87395378e+13]
# [ 1.70143675e+13 -4.87395378e+13]
# [1.70143675e+13 2.11749871e+14]
# [-7.39192507e+13  2.11749871e+14]
# [-7.39192507e+13 -9.19951435e+14]
# [ 3.21143623e+14 -9.19951435e+14]
# [3.21143623e+14 3.99674692e+15]
# [-1.39521472e+15  3.99674692e+15]
# [-1.39521472e+15 -1.73639448e+16]
# [ 6.06153752e+15 -1.73639448e+16]
# [6.06153752e+15 7.54379961e+16]
# [-2.63344678e+16  7.54379961e+16]
# [-2.63344678e+16 -3.27741843e+17]
# [ 1.14410608e+17 -3.27741843e+17]
# [1.14410608e+17 1.42388081e+18]
# [-4.97059112e+17  1.42388081e+18]
# [-4.97059112e+17 -6.18607792e+18]
# [ 2.15948299e+18 -6.18607792e+18]
# [2.15948299e+18 2.68755359e+19]
# [-9.38191588e+18  2.68755359e+19]
# [-9.38191588e+18 -1.16761289e+20]
# [ 4.07599162e+19 -1.16761289e+20]
# [4.07599162e+19 5.07271693e+20]
# [-1.77082249e+20  5.07271693e+20]
# [-1.77082249e+20 -2.20385174e+21]
# [ 7.69337279e+20 -2.20385174e+21]
# [7.69337279e+20 9.57467680e+21]
# [-3.34240078e+21  9.57467680e+21]
# [-3.34240078e+21 -4.15973697e+22]
# [ 1.45211253e+22 -4.15973697e+22]
# [1.45211253e+22 1.80720582e+23]
# [-6.30873114e+22  1.80720582e+23]
# [-6.30873114e+22 -7.85144088e+23]
# [ 2.74084052e+23 -7.85144088e+23]
# [2.74084052e+23 3.41107377e+24]
# [-1.19076350e+24  3.41107377e+24]
# [-1.19076350e+24 -1.48194764e+25]
# [ 5.17329521e+24 -1.48194764e+25]
# [5.17329521e+24 6.43835037e+25]
# [-2.24754817e+25  6.43835037e+25]
# [-2.24754817e+25 -2.79715385e+26]
# [ 9.76451678e+25 -2.79715385e+26]
# [9.76451678e+25 1.21522894e+27]
# [-4.24221332e+26  1.21522894e+27]
# [-4.24221332e+26 -5.27958577e+27]
# [ 1.84303784e+27 -5.27958577e+27]
# [1.84303784e+27 2.29372631e+28]
# [-8.00711375e+27  2.29372631e+28]
# [-8.00711375e+27 -9.96513862e+28]
# [ 3.47870616e+28 -9.96513862e+28]
# [3.47870616e+28 4.32937387e+29]
# [-1.51133066e+29  4.32937387e+29]
# [-1.51133066e+29 -1.88090491e+30]
# [ 6.56600548e+29 -1.88090491e+30]
# [6.56600548e+29 8.17162797e+30]
# [-2.85261386e+30  8.17162797e+30]
# [-2.85261386e+30 -3.55017968e+31]
# [ 1.23932364e+31 -3.55017968e+31]
# [1.23932364e+31 1.54238247e+32]
# [-5.38426570e+31  1.54238247e+32]
# [-5.38426570e+31 -6.70091067e+32]
# [ 2.33920471e+32 -6.70091067e+32]
# [2.33920471e+32 2.91122369e+33]
# [-1.01627204e+33  2.91122369e+33]
# [-1.01627204e+33 -1.26478680e+34]
# [ 4.41521366e+33 -1.26478680e+34]
# [4.41521366e+33 5.49489086e+34]
# [-1.91819817e+34  5.49489086e+34]
# [-1.91819817e+34 -2.38726603e+35]
# [ 8.33364929e+34 -2.38726603e+35]
# [8.33364929e+34 1.03715237e+36]
# [-3.62057016e+35  1.03715237e+36]
# [-3.62057016e+35 -4.50592868e+36]
# [ 1.57296375e+36 -4.50592868e+36]
# [1.57296375e+36 1.95760948e+37]
# [-6.83377164e+36  1.95760948e+37]
# [-6.83377164e+36 -8.50487251e+37]
# [ 2.96894539e+37 -8.50487251e+37]
# [2.96894539e+37 3.69495842e+38]
# [-1.28986410e+38  3.69495842e+38]
# [-1.28986410e+38 -1.60528188e+39]
# [ 5.60383971e+38 -1.60528188e+39]
# [5.60383971e+38 6.97417836e+39]
# [-2.43459907e+39  6.97417836e+39]
# [-2.43459907e+39 -3.02994536e+40]
# [ 1.05771630e+40 -3.02994536e+40]
# [1.05771630e+40 1.31636566e+41]
# [-4.59526907e+40  1.31636566e+41]
# [-4.59526907e+40 -5.71897624e+41]
# [ 1.99642359e+41 -5.71897624e+41]
# [1.99642359e+41 2.48462036e+42]
# [-8.67350117e+41  2.48462036e+42]
# [-8.67350117e+41 -1.07944815e+43]
# [ 3.76821947e+42 -1.07944815e+43]
# [3.76821947e+42 4.68968351e+43]
# [-1.63711028e+43  4.68968351e+43]
# [-1.63711028e+43 -2.03744213e+44]
# [ 7.11245749e+43 -2.03744213e+44]
# [7.11245749e+43 8.85170699e+44]
# [-3.09002100e+44  8.85170699e+44]
# [-3.09002100e+44 -3.84564133e+45]
# [ 1.34246564e+45 -3.84564133e+45]
# [1.34246564e+45 1.67074636e+46]
# [-5.83236810e+45  1.67074636e+46]
# [-5.83236810e+45 -7.25859009e+46]
# [ 2.53388367e+46 -7.25859009e+46]
# [2.53388367e+46 3.15350859e+47]
# [-1.10085069e+47  3.15350859e+47]
# [-1.10085069e+47 -1.37004795e+48]
# [ 4.78266727e+47 -1.37004795e+48]
# [4.78266727e+47 5.95219997e+48]
# [-2.07783910e+48  5.95219997e+48]
# [-2.07783910e+48 -2.58594486e+49]
# [ 9.02721243e+48 -2.58594486e+49]
# [9.02721243e+48 1.12346878e+50]
# [-3.92189001e+49  1.12346878e+50]
# [-3.92189001e+49 -4.88093198e+50]
# [ 1.70387275e+50 -4.88093198e+50]
# [1.70387275e+50 2.12053040e+51]
# [-7.40250833e+50  2.12053040e+51]
# [-7.40250833e+50 -9.21268561e+51]
# [ 3.21603415e+51 -9.21268561e+51]
# [3.21603415e+51 4.00246919e+52]
# [-1.39721230e+52  4.00246919e+52]
# [-1.39721230e+52 -1.73888053e+53]
# [ 6.07021603e+52 -1.73888053e+53]
# [6.07021603e+52 7.55460032e+53]
# [-2.63721717e+53  7.55460032e+53]
# [-2.63721717e+53 -3.28211082e+54]
# [ 1.14574413e+54 -3.28211082e+54]
# [1.14574413e+54 1.42591943e+55]
# [-4.97770769e+54  1.42591943e+55]
# [-4.97770769e+54 -6.19493473e+55]
# [ 2.16257479e+55 -6.19493473e+55]
# [2.16257479e+55 2.69140145e+56]
# [-9.39534829e+55  2.69140145e+56]
# [-9.39534829e+55 -1.16928460e+57]
# [ 4.08182735e+56 -1.16928460e+57]
# [4.08182735e+56 5.07997971e+57]
# [-1.77335784e+57  5.07997971e+57]
# [-1.77335784e+57 -2.20700707e+58]
# [ 7.70438765e+57 -2.20700707e+58]
# [7.70438765e+57 9.58838518e+58]
# [-3.34718621e+58  9.58838518e+58]
# [-3.34718621e+58 -4.16569261e+59]
# [ 1.45419156e+59 -4.16569261e+59]
# [1.45419156e+59 1.80979326e+60]
# [-6.31776356e+59  1.80979326e+60]
# [-6.31776356e+59 -7.86268205e+60]
# [ 2.74476468e+60 -7.86268205e+60]
# [2.74476468e+60 3.41595752e+61]
# [-1.19246836e+61  3.41595752e+61]
# [-1.19246836e+61 -1.48406940e+62]
# [ 5.18070199e+61 -1.48406940e+62]
# [5.18070199e+61 6.44756838e+62]
# [-2.25076606e+62  6.44756838e+62]
# [-2.25076606e+62 -2.80115863e+63]
# [ 9.77849697e+62 -2.80115863e+63]
# [9.77849697e+62 1.21696882e+64]
# [-4.24828704e+63  1.21696882e+64]
# [-4.24828704e+63 -5.28714473e+64]
# [ 1.84567658e+64 -5.28714473e+64]
# [1.84567658e+64 2.29701032e+65]
